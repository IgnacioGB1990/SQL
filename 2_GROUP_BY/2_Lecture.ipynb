# %% [markdown]
# ## `GROUP BY` allow us to aggregate data and apply functions to better understand how data is distributed per category.
#
# Most Common Aggregate Functions:
# - AVG() - returns average value in decimal places (you can use ROUND() to specify precision after the decimal)
# - COUNT() - returns number of values
# - MAX() - returns maximum value
# - MIN() - returns minimum value
# - SUM() - returns the sum of all values
#
# Note: Aggregate funciton calls happen only in the SELECT clause or the HAVING clause.

# %% [markdown]
# ### Libraries and function setup to perform queries

# %%
# Libraries
import pandas as pd
import sqlite3

cnx = sqlite3.connect('./data/jobs.db')

# Definimos la función para hacer queries.
def sql_query(query):
    return pd.read_sql(query, cnx)

# %% [markdown]
# ### Check our dataset. We have included Date timestamp column

# %%
query = """
SELECT * FROM jobs
"""
sql_query(query)
# Out:
#            Name     Surname                Country                     Job
# 0          John      Morris                 Israel   Agricultural engineer  \
# 1       Anthony      Thomas                Belgium     Trade mark attorney
# 2        Martin       Singh              Gibraltar               Homeopath
# 3       Stephen      Norris  Saint Kitts and Nevis    Commissioning editor
# 4      Kimberly      Rivera             Guadeloupe          Futures trader
# ...         ...         ...                    ...                     ...
# 9995      David      Miller            Saint Lucia   Engineer, maintenance
# 9996  Christian     Padilla                Austria       Fish farm manager
# 9997     Albert    Anderson                Senegal     Colour technologist
# 9998   Jennifer  Washington                Burundi  Psychotherapist, child
# 9999     Carlos        Snow               Zimbabwe   Merchant navy officer
#
#       Age  Experience  Salary                 Date
# 0      47          14   99899  2023-05-14 15:29:09
# 1      26          12   32322  2023-05-04 18:23:39
# 2      41          13   89678  2023-05-14 15:48:41
# 3      39           8   74179  2023-05-12 02:40:30
# 4      32          10   60126  2023-05-14 16:06:49
# ...   ...         ...     ...                  ...
# 9995   60          11   40923  2023-05-05 07:39:48
# 9996   60           3   92616  2023-05-08 14:31:47
# 9997   47           5   51677  2023-05-17 16:17:23
# 9998   39          10   88505  2023-05-09 07:24:31
# 9999   38          15   33005  2023-05-05 10:13:55
#
# [10000 rows x 8 columns]

# %%
query = """
SELECT MAX(Salary),
MIN(Salary),
AVG(Salary)

FROM jobs
"""
sql_query(query)
# Out:
#    MAX(Salary)  MIN(Salary)  AVG(Salary)
# 0        99997        30003   64861.5492

# %%
query = """
SELECT ROUND(AVG(Salary),2)

FROM jobs
"""
sql_query(query)
# Out:
#    ROUND(AVG(Salary),2)
# 0              64861.55

# %% [markdown]
# - `SELECT` category_col, `AGG`(data_col)
# `FROM` table
# `GROUP BY` category_col
#
# - The `GROUP BY` clause must appear right after a `FROM` or `WHERE` statement.

# %% [markdown]
# In its simplest form `GROUP BY` acts as the same as `DISTINCT`

# %%
query = """
SELECT Name FROM jobs
GROUP BY Name
ORDER BY Name
"""
sql_query(query)
# Out:
#         Name
# 0      Aaron
# 1    Abigail
# 2       Adam
# 3     Adrian
# 4    Adriana
# ..       ...
# 658  Yolanda
# 659   Yvette
# 660   Yvonne
# 661  Zachary
# 662      Zoe
#
# [663 rows x 1 columns]

# %% [markdown]
# Lets check it is similar as `DISTINCT`

# %%
query = """
SELECT DISTINCT(Name) FROM jobs
ORDER BY Name
"""
sql_query(query)
# Out:
#         Name
# 0      Aaron
# 1    Abigail
# 2       Adam
# 3     Adrian
# 4    Adriana
# ..       ...
# 658  Yolanda
# 659   Yvette
# 660   Yvonne
# 661  Zachary
# 662      Zoe
#
# [663 rows x 1 columns]

# %%
query = """
SELECT * FROM jobs
"""
sql_query(query)
# Out:
#            Name     Surname                Country                     Job
# 0          John      Morris                 Israel   Agricultural engineer  \
# 1       Anthony      Thomas                Belgium     Trade mark attorney
# 2        Martin       Singh              Gibraltar               Homeopath
# 3       Stephen      Norris  Saint Kitts and Nevis    Commissioning editor
# 4      Kimberly      Rivera             Guadeloupe          Futures trader
# ...         ...         ...                    ...                     ...
# 9995      David      Miller            Saint Lucia   Engineer, maintenance
# 9996  Christian     Padilla                Austria       Fish farm manager
# 9997     Albert    Anderson                Senegal     Colour technologist
# 9998   Jennifer  Washington                Burundi  Psychotherapist, child
# 9999     Carlos        Snow               Zimbabwe   Merchant navy officer
#
#       Age  Experience  Salary                 Date
# 0      47          14   99899  2023-05-14 15:29:09
# 1      26          12   32322  2023-05-04 18:23:39
# 2      41          13   89678  2023-05-14 15:48:41
# 3      39           8   74179  2023-05-12 02:40:30
# 4      32          10   60126  2023-05-14 16:06:49
# ...   ...         ...     ...                  ...
# 9995   60          11   40923  2023-05-05 07:39:48
# 9996   60           3   92616  2023-05-08 14:31:47
# 9997   47           5   51677  2023-05-17 16:17:23
# 9998   39          10   88505  2023-05-09 07:24:31
# 9999   38          15   33005  2023-05-05 10:13:55
#
# [10000 rows x 8 columns]

# %% [markdown]
# Imagine we wanted to find the Aggregate all the people´s salary aged 25. We could do:

# %%
query = """
SELECT Age, SUM(Salary) FROM jobs
WHERE Age = 25
"""

sql_query(query)
# Out:
#    Age  SUM(Salary)
# 0   25     17883740

# %% [markdown]
# However, with `GROUP BY` we could do it automatically for each category that it detects.

# %%
query = """
SELECT Age, SUM(Salary) FROM jobs
GROUP BY Age
"""

sql_query(query)
# Out:
#     Age  SUM(Salary)
# 0    25     17883740
# 1    26     17620498
# 2    27     18293741
# 3    28     16967496
# 4    29     19248178
# 5    30     17805555
# 6    31     17441064
# 7    32     18164584
# 8    33     17511653
# 9    34     16025252
# 10   35     17555502
# 11   36     17747243
# 12   37     18100125
# 13   38     16554126
# 14   39     17801274
# 15   40     19436419
# 16   41     18182901
# 17   42     16390727
# 18   43     19299166
# 19   44     18583403
# 20   45     16837943
# 21   46     18318463
# 22   47     18275199
# 23   48     18205402
# 24   49     17948160
# 25   50     17320516
# 26   51     18690428
# 27   52     18672238
# 28   53     18585500
# 29   54     17171848
# 30   55     18936598
# 31   56     19131962
# 32   57     18211890
# 33   58     17971063
# 34   59     18706447
# 35   60     19019188

# %% [markdown]
# And a typicall querie would be to find the age where the salary is highest by adding ORDER BY SUM

# %%
query = """
SELECT Age, SUM(Salary) FROM jobs
GROUP BY Age
ORDER BY SUM(Salary) DESC
"""

sql_query(query)
# Out:
#     Age  SUM(Salary)
# 0    40     19436419
# 1    43     19299166
# 2    29     19248178
# 3    56     19131962
# 4    60     19019188
# 5    55     18936598
# 6    59     18706447
# 7    51     18690428
# 8    52     18672238
# 9    53     18585500
# 10   44     18583403
# 11   46     18318463
# 12   27     18293741
# 13   47     18275199
# 14   57     18211890
# 15   48     18205402
# 16   41     18182901
# 17   32     18164584
# 18   37     18100125
# 19   58     17971063
# 20   49     17948160
# 21   25     17883740
# 22   30     17805555
# 23   39     17801274
# 24   36     17747243
# 25   26     17620498
# 26   35     17555502
# 27   33     17511653
# 28   31     17441064
# 29   50     17320516
# 30   54     17171848
# 31   28     16967496
# 32   45     16837943
# 33   38     16554126
# 34   42     16390727
# 35   34     16025252

# %% [markdown]
# What if we wanted to know hoy many people exists by category in dataset? Let´s see if it balanced.
#
# We can check first how we did before individually.

# %%
query = """
SELECT COUNT(*) FROM jobs
WHERE Age = 39
"""

sql_query(query)
# Out:
#    COUNT(*)
# 0       278

# %% [markdown]
# Or we can use `GROUP BY`

# %%
query = """
SELECT Age, COUNT(Salary) FROM jobs
GROUP BY Age
ORDER BY COUNT(Salary) DESC
"""

sql_query(query)
# Out:
#     Age  COUNT(Salary)
# 0    29            301
# 1    43            301
# 2    40            298
# 3    52            298
# 4    55            296
# 5    60            295
# 6    51            289
# 7    48            288
# 8    56            288
# 9    32            287
# 10   44            284
# 11   53            284
# 12   46            283
# 13   27            282
# 14   36            279
# 15   41            279
# 16   37            278
# 17   39            278
# 18   59            278
# 19   49            276
# 20   57            276
# 21   30            275
# 22   47            275
# 23   26            272
# 24   33            272
# 25   58            269
# 26   25            268
# 27   28            265
# 28   31            265
# 29   54            265
# 30   42            264
# 31   50            263
# 32   35            262
# 33   45            258
# 34   38            256
# 35   34            253

# %% [markdown]
# Say you wanted to know how many people Aged 25 are Academic librarian =>2

# %%
query = """
SELECT Age, Job, COUNT(*) FROM jobs
GROUP BY Age,Job

"""

sql_query(query)
# Out:
#       Age                       Job  COUNT(*)
# 0      25        Academic librarian         1
# 1      25     Accommodation manager         1
# 2      25                     Actor         1
# 3      25                   Actuary         1
# 4      25             Acupuncturist         1
# ...   ...                       ...       ...
# 8131   60       Trade mark attorney         1
# 8132   60         Transport planner         1
# 8133   60              Tree surgeon         1
# 8134   60             Warden/ranger         1
# 8135   60  Waste management officer         1
#
# [8136 rows x 3 columns]

# %% [markdown]
# Or we could find out their average salary

# %%
query = """
SELECT Age, Job, AVG(Salary) FROM jobs
GROUP BY Age,Job
"""

sql_query(query)
# Out:
#       Age                       Job  AVG(Salary)
# 0      25        Academic librarian      74209.0
# 1      25     Accommodation manager      82210.0
# 2      25                     Actor      62203.0
# 3      25                   Actuary      69656.0
# 4      25             Acupuncturist      74659.0
# ...   ...                       ...          ...
# 8131   60       Trade mark attorney      79421.0
# 8132   60         Transport planner      69133.0
# 8133   60              Tree surgeon      88044.0
# 8134   60             Warden/ranger      96898.0
# 8135   60  Waste management officer      54121.0
#
# [8136 rows x 3 columns]

# %% [markdown]
# ### Handling Dates
#
# If we have dates in timestamp format, that is with hour, minute and seconds and we want to perform GROUP BY we should first convert it with `DATE` function

# %%
query = """
SELECT Date FROM jobs
"""

sql_query(query)
# Out:
#                      Date
# 0     2023-05-14 15:29:09
# 1     2023-05-04 18:23:39
# 2     2023-05-14 15:48:41
# 3     2023-05-12 02:40:30
# 4     2023-05-14 16:06:49
# ...                   ...
# 9995  2023-05-05 07:39:48
# 9996  2023-05-08 14:31:47
# 9997  2023-05-17 16:17:23
# 9998  2023-05-09 07:24:31
# 9999  2023-05-05 10:13:55
#
# [10000 rows x 1 columns]

# %% [markdown]
# `DATE` removes timestamp information.

# %%
query = """
SELECT DATE(Date) FROM jobs
"""

sql_query(query)
# Out:
#       DATE(Date)
# 0     2023-05-14
# 1     2023-05-04
# 2     2023-05-14
# 3     2023-05-12
# 4     2023-05-14
# ...          ...
# 9995  2023-05-05
# 9996  2023-05-08
# 9997  2023-05-17
# 9998  2023-05-09
# 9999  2023-05-05
#
# [10000 rows x 1 columns]

# %% [markdown]
# In this example we can see an agregate per date of all the salary

# %%
query = """
SELECT DATE(Date), SUM(Salary) FROM jobs
GROUP BY DATE(Date)
ORDER BY SUM(Salary) ASC
"""

sql_query(query)
# Out:
#     DATE(Date)  SUM(Salary)
# 0   2023-05-25     18676524
# 1   2023-05-27     18975663
# 2   2023-05-23     19526378
# 3   2023-05-16     19780724
# 4   2023-05-19     20012440
# 5   2023-05-12     20329434
# 6   2023-05-01     20458362
# 7   2023-05-22     20640485
# 8   2023-05-15     20676680
# 9   2023-05-30     20792186
# 10  2023-05-24     21013324
# 11  2023-05-18     21278925
# 12  2023-05-05     21332901
# 13  2023-05-06     21404133
# 14  2023-05-04     21410376
# 15  2023-05-10     21669486
# 16  2023-05-09     21930697
# 17  2023-05-21     21974013
# 18  2023-05-13     22164157
# 19  2023-05-08     22169434
# 20  2023-05-02     22474526
# 21  2023-05-26     22559880
# 22  2023-05-14     22810731
# 23  2023-05-07     22833734
# 24  2023-05-20     22837121
# 25  2023-05-03     23063716
# 26  2023-05-29     23350497
# 27  2023-05-28     23662626
# 28  2023-05-17     23812952
# 29  2023-05-11     24993387

# %% [markdown]
# ### `HAVING` allows us to filter **after** an aggregation that has already taken place.
#
# It allows us to use the aggregate result as a filter along with a GROUP BY

# %%
query = """
SELECT Job, SUM(Salary) FROM jobs
GROUP BY Job
HAVING SUM(Salary) >1600000
"""

sql_query(query)
# Out:
#                            Job  SUM(Salary)
# 0            Company secretary      1723466
# 1   Designer, fashion/clothing      1634106
# 2  Health and safety inspector      1638219
# 3               Health visitor      1709550
# 4               Police officer      1874566
# 5     Surveyor, rural practice      1623350
# 6                  Tax adviser      1653346

# %% [markdown]
# Corregida

# %%
SELECT customer_id, SUM(amount) 
FROM payment
WHERE staff_id =2
GROUP BY customer_id
HAVING SUM(AMOUNT)>100

# %% [markdown]
# Mi forma

# %%
SELECT customer_id, SUM(amount) 
FROM payment
GROUP BY staff_id, customer_id
HAVING staff_id = 2 AND SUM(amount)>100
