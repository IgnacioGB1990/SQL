# %% [markdown]
# ## Lecture objective:
#
# The **goal** of this lecture is to get to know the following basic SQL commands:
#
# - `SELECT` columns `FROM` table
# - `LIMIT`
# - `DISTINCT`
# - `COUNT`
# - `WHERE`
# - `AND`, `OR` and `NOT`
# - `ORDER BY`
# - `BETWEEN`
# - `IN`
# - `LIKE` and `ILIKE`
#
# and practice with **comparison operators**:
# - = equal
# - \> greater than
# - < less than
# - \>= greater than or equal to
# - <= less than or equal to
# - <> or != not equal to

# %% [markdown]
# ### Libraries and function setup to perform queries

# %%
# Libraries
import pandas as pd
import sqlite3



cnx = sqlite3.connect('./data/jobs.db')

# Definimos la función para hacer queries.
def sql_query(query):
    return pd.read_sql(query, cnx)

# %% [markdown]
# ### `SELECT` columns `FROM` table
#
# Let´s take a look to our table *jobs* to see what information we have

# %%
query = """
SELECT * FROM jobs
"""
sql_query(query)
# Out:
#             Name    Surname     Country                                   Job
# 0       Jennifer      Gomez       Benin                      Engineer, mining  \
# 1          Julia    Garrett       Italy                            Bookseller
# 2       Courtney    Freeman        Niue                  Pharmacist, hospital
# 3         Sheena   Faulkner        Peru             Estate manager/land agent
# 4         Cheryl     Arnold    Pakistan                   Colour technologist
# ...          ...        ...         ...                                   ...
# 9995     Makayla     Miller      Kuwait                         Stage manager
# 9996     William  Underwood        Mali      Training and development officer
# 9997       Scott      Lewis  Montenegro  International aid/development worker
# 9998  Jacqueline       Diaz   Venezuela            Contracting civil engineer
# 9999     Gregory      Davis  Luxembourg                    Secretary, company
#
#       Age  Experience  Salary
# 0      27           9   79156
# 1      58           1   67262
# 2      44          15   44105
# 3      56           6   71914
# 4      27           2   90405
# ...   ...         ...     ...
# 9995   26           3   41031
# 9996   31           3   77919
# 9997   40           3   84261
# 9998   50          10   94421
# 9999   35           6   47573
#
# [10000 rows x 7 columns]

# %% [markdown]
# ### `LIMIT`
#
# That is great, but we only want to see the 5 first results. We can do that with LIMIT

# %%
query = """
SELECT * FROM jobs
LIMIT 5
"""
sql_query(query)
# Out:
#        Name   Surname   Country                        Job  Age  Experience
# 0  Jennifer     Gomez     Benin           Engineer, mining   27           9  \
# 1     Julia   Garrett     Italy                 Bookseller   58           1
# 2  Courtney   Freeman      Niue       Pharmacist, hospital   44          15
# 3    Sheena  Faulkner      Peru  Estate manager/land agent   56           6
# 4    Cheryl    Arnold  Pakistan        Colour technologist   27           2
#
#    Salary
# 0   79156
# 1   67262
# 2   44105
# 3   71914
# 4   90405

# %% [markdown]
# ### `DISTINCT`
#
# Let us see how many different unique job positions does the table contain.

# %%
query = """
SELECT DISTINCT Job FROM jobs
"""
sql_query(query)
# Out:
#                                Job
# 0                 Engineer, mining
# 1                       Bookseller
# 2             Pharmacist, hospital
# 3        Estate manager/land agent
# 4              Colour technologist
# ..                             ...
# 634           Newspaper journalist
# 635   Education officer, community
# 636       Horticultural consultant
# 637    Lecturer, further education
# 638  Engineer, civil (contracting)
#
# [639 rows x 1 columns]

# %% [markdown]
# ### `COUNT`
#
# That is great, but we only want to know how many different jobs there are.

# %%
query = """
SELECT COUNT( DISTINCT Job) FROM jobs
"""
sql_query(query)
# Out:
#    COUNT( DISTINCT Job)
# 0                   639

# %% [markdown]
# ### `WHERE`
#
# Let us find those people who are from a particular country, i.e. from Spain.

# %%
query = """
SELECT * FROM jobs
WHERE Country = "Spain"
"""
sql_query(query)
# Out:
#         Name    Surname Country                            Job  Age
# 0    Patrick     Rogers   Spain            Scientist, forensic   55  \
# 1     Thomas     Garcia   Spain       Computer games developer   54
# 2        Bob      Brown   Spain          Multimedia specialist   32
# 3       Mary     Little   Spain                 Retail manager   32
# 4   Jennifer     Morgan   Spain                     Astronomer   43
# 5    Richard    Hampton   Spain         Operational researcher   30
# 6      Jason      Boone   Spain       Local government officer   39
# 7   Patricia   Thompson   Spain    Clinical research associate   60
# 8   Kathleen      Fritz   Spain         Psychotherapist, child   40
# 9      Haley     Warren   Spain      Occupational psychologist   26
# 10    Nathan      Chang   Spain              Transport planner   45
# 11    Joseph       Bass   Spain             Field seismologist   30
# 12  Kimberly     Pruitt   Spain              Social researcher   27
# 13    Gloria      Simon   Spain        Physiological scientist   53
# 14    Joseph   Caldwell   Spain    Scientist, research (maths)   55
# 15       Kim     Kelley   Spain                   Sports coach   53
# 16   Heather   Galloway   Spain             Engineer, drilling   41
# 17     April      Gomez   Spain          IT sales professional   45
# 18     Scott     Wilson   Spain            Corporate treasurer   41
# 19    Dustin      Pitts   Spain        Agricultural consultant   55
# 20    Donald  Valentine   Spain     Surveyor, building control   44
# 21     Maria    Herring   Spain  Engineer, civil (contracting)   33
# 22    Andrew  Hernandez   Spain                   Web designer   58
# 23   Timothy      Weber   Spain                  Buyer, retail   54
# 24   Brandon       Long   Spain                 Engineer, site   41
# 25       Ana  Henderson   Spain              Systems developer   42
# 26      Tony      White   Spain         Air traffic controller   28
# 27     Cindy    Simmons   Spain       Print production planner   47
# 28      Erik    Everett   Spain         Engineer, agricultural   54
#
#     Experience  Salary
# 0           11   38447
# 1            2   51497
# 2           14   95244
# 3            8   46793
# 4            1   63334
# 5            4   66890
# 6            1   91562
# 7            6   69307
# 8            9   35535
# 9            5   74294
# 10           3   38034
# 11           6   37692
# 12          14   71308
# 13           1   50166
# 14           2   74018
# 15           3   63690
# 16           8   36960
# 17          10   59246
# 18           1   55176
# 19           5   49160
# 20          14   75700
# 21          13   79310
# 22           4   77758
# 23          13   79466
# 24           2   58771
# 25          12   41154
# 26           7   99503
# 27           4   46048
# 28           8   70546

# %% [markdown]
# ### `AND`
# What if we want to find only spanish citizens that are older than 50 and salary is under 50k. We can use AND command as much as we like.

# %%
query = """
SELECT * FROM jobs
WHERE Country = "Spain" AND Age > 50 AND Salary < 50000
"""
sql_query(query)
# Out:
#       Name Surname Country                      Job  Age  Experience  Salary
# 0  Patrick  Rogers   Spain      Scientist, forensic   55          11   38447
# 1   Dustin   Pitts   Spain  Agricultural consultant   55           5   49160

# %% [markdown]
# Imagine we wanted to find out spanish and french citizens. Initially we might try something like this.

# %%
query = """
SELECT * FROM jobs
WHERE Country = "Spain" AND Country = "France"
"""
sql_query(query)
# Out:
# Empty DataFrame
# Columns: [Name, Surname, Country, Job, Age, Experience, Salary]
# Index: []

# %% [markdown]
# We can see that the query does not return any results. This is because a column cannot have two different values in the same row.

# %% [markdown]
# ### `OR`
#
# Lets see with if we can find an alternative.

# %%
query = """
SELECT * FROM jobs
WHERE Country = "Spain" OR Country = "France"
"""
sql_query(query)
# Out:
#        Name   Surname Country                                Job  Age
# 0   Charles    Medina  France                         Bookseller   60  \
# 1      Jodi  Bradford  France          Public affairs consultant   49
# 2      Mary     Boyer  France                     Cytogeneticist   54
# 3   Patrick    Rogers   Spain                Scientist, forensic   55
# 4      Alec     Lynch  France  Sales promotion account executive   32
# ..      ...       ...     ...                                ...  ...
# 65   Kristi    Juarez  France                     Futures trader   39
# 66  Timothy   Pittman  France                Information officer   39
# 67     Erik   Everett   Spain             Engineer, agricultural   54
# 68   Angela    Robles  France     Commercial art gallery manager   41
# 69   Rachel      Neal  France              Administrator, sports   35
#
#     Experience  Salary
# 0            2   82257
# 1           15   63459
# 2            3   73941
# 3           11   38447
# 4            7   50754
# ..         ...     ...
# 65           3   47727
# 66          13   76922
# 67           8   70546
# 68           1   70046
# 69           8   43225
#
# [70 rows x 7 columns]

# %% [markdown]
# ### `IN`
#
# However, the code above seems a bit repetitive. Is there something a bit more cleaner?

# %%
query = """
SELECT * FROM jobs
WHERE Country IN("Spain","France")
"""
sql_query(query)
# Out:
#        Name   Surname Country                                Job  Age
# 0   Charles    Medina  France                         Bookseller   60  \
# 1      Jodi  Bradford  France          Public affairs consultant   49
# 2      Mary     Boyer  France                     Cytogeneticist   54
# 3   Patrick    Rogers   Spain                Scientist, forensic   55
# 4      Alec     Lynch  France  Sales promotion account executive   32
# ..      ...       ...     ...                                ...  ...
# 65   Kristi    Juarez  France                     Futures trader   39
# 66  Timothy   Pittman  France                Information officer   39
# 67     Erik   Everett   Spain             Engineer, agricultural   54
# 68   Angela    Robles  France     Commercial art gallery manager   41
# 69   Rachel      Neal  France              Administrator, sports   35
#
#     Experience  Salary
# 0            2   82257
# 1           15   63459
# 2            3   73941
# 3           11   38447
# 4            7   50754
# ..         ...     ...
# 65           3   47727
# 66          13   76922
# 67           8   70546
# 68           1   70046
# 69           8   43225
#
# [70 rows x 7 columns]

# %% [markdown]
# ### `ORDER BY`
#
# Helps us sort rows based on column value, in either ascending or descending order.
#
# - use `ASC` to sort in ascending order
# - use `DESC` to sort in descending order
# - If you leave it blank, `ORDER BY` uses `ASC` by default.
#
# It is placed towards the end of the query. We want to do any selection and filtering first, before finally sorting.
#
#
# Let us see who are the best paid by sorting by salary

# %% [markdown]
# We can combine and sort by age

# %%
query = """
SELECT * FROM jobs
WHERE Country IN("Spain","France")
ORDER BY salary DESC, Age ASC
"""
sql_query(query)
# Out:
#            Name   Surname Country                              Job  Age
# 0          Tony     White   Spain           Air traffic controller   28  \
# 1           Bob     Brown   Spain            Multimedia specialist   32
# 2         Emily       Lee  France              Engineer, petroleum   40
# 3         Jason     Boone   Spain         Local government officer   39
# 4          John  Crawford  France                     Chiropractor   42
# ..          ...       ...     ...                              ...  ...
# 65      Suzanne  Anderson  France           Chief Strategy Officer   51
# 66  Christopher  Robinson  France  Geophysicist/field seismologist   34
# 67        Frank    Chavez  France           Applications developer   43
# 68       Deanna      Bond  France             Engineer, biomedical   41
# 69      Spencer  Thompson  France                Building surveyor   27
#
#     Experience  Salary
# 0            7   99503
# 1           14   95244
# 2            8   92922
# 3            1   91562
# 4            9   87304
# ..         ...     ...
# 65           5   32339
# 66           1   30672
# 67           6   30616
# 68          11   30487
# 69          11   30266
#
# [70 rows x 7 columns]

# %% [markdown]
# ### `BETWEEN` operator can be used to match a value against a range of values:
# - value BETWEEN low AND high
#
# It is the same as saying:
# - value \>= low AND value \<= high
#
# Can combine with `NOT BETWEEN`:
# - value \< low OR value \> high
# - value NOT BETWEEN low AND high
#
# Can also be used with dates. Note that you need to format dates in the ISO 8601 standard format, which is YYYY-MM-DD
# - date BETWEEN "2007-01-01" AND "2007-02-01"
#
# Lets put an example to see it in practice. We will select people aging between 30 and 33 (inclusive) and salaries not comprehended between 50k and 70k.

# %%
query = """
SELECT * FROM jobs
WHERE Age BETWEEN 30 AND 33
AND Salary NOT BETWEEN 50000 AND 70000
"""
sql_query(query)
# Out:
#          Name    Surname                               Country
# 0     Michael     Pierce                               Morocco  \
# 1        Mary     Foster  United States Minor Outlying Islands
# 2       Sarah     Ashley                                Latvia
# 3      Martin    Pacheco         Holy See (Vatican City State)
# 4      Curtis     French                     Wallis and Futuna
# ..        ...        ...                                   ...
# 794   Patrick   Robinson                               Belgium
# 795      Ryan     Barker                               Lebanon
# 796  Nicholas    Kennedy                    Dominican Republic
# 797    Amanda       Shaw                            San Marino
# 798   William  Underwood                                  Mali
#
#                                     Job  Age  Experience  Salary
# 0                Therapist, nutritional   30           6   97697
# 1             Trading standards officer   30           4   80071
# 2       Geophysicist/field seismologist   30           9   31180
# 3    Tourist information centre manager   32           3   80653
# 4                Psychotherapist, child   33           1   96881
# ..                                  ...  ...         ...     ...
# 794        Administrator, Civil Service   32           4   34669
# 795                    Graphic designer   30          14   49835
# 796                  Materials engineer   30           7   40947
# 797             Agricultural consultant   32           4   78405
# 798    Training and development officer   31           3   77919
#
# [799 rows x 7 columns]

# %% [markdown]
# ### `LIKE` (case-sensitive) and `ILIKE` (case-insensitive) operator allows us to perform pattern matching against string data with the use of wildcard characters.
#
# - Percent %
#     - Matches any sequence of characters
# - Underscore _
#     - Matches any single character
#
# Examples %:
# - All names that begin with an "A"
#     - `WHERE` name `LIKE` 'A%'
# - All names that end with an 'a'
#     - `WHERE` name `LIKE` '%a'
#
# Examples _:
# - Using the underscore allows us to replace just a single character.
#     - Get all pokemon
#     - WHERE name LIKE 'Char_"
#
# - You can use multiple underscores
# - Imagine we had version string codes in the format 'Version#A4', 'Version#B7', etc ...
#     - WHERE value LIKE 'Version# _ _'
# - We can also combine pattern matching operators to create more complex patterns
#     - WHERE name LIKE '`_`her`%`'
#         - `C`her`yl`
#         - `T`her`esa`
#         - `S`her`ri`

# %%
query = """
SELECT * FROM jobs
WHERE Name LIKE "_her%"

"""
sql_query(query)
# Out:
#        Name     Surname               Country
# 0    Cheryl      Arnold              Pakistan  \
# 1    Sherri    Garrison        Cayman Islands
# 2    Cheryl  Richardson                Gambia
# 3   Theresa     Sherman              Zimbabwe
# 4    Cheryl    Peterson               Vietnam
# ..      ...         ...                   ...
# 58   Sherry       Smith              Paraguay
# 59   Cheryl      Cooley           Netherlands
# 60   Sherri     Herrera                 Gabon
# 61   Sherri       James         Cote d'Ivoire
# 62   Sherri      Nelson  Netherlands Antilles
#
#                                                   Job  Age  Experience  Salary
# 0                                 Colour technologist   27           2   90405
# 1                   Planning and development surveyor   46          11   66866
# 2                    Education officer, environmental   25          13   54225
# 3                    Training and development officer   51           2   46474
# 4                                           Paramedic   46          10   47632
# ..                                                ...  ...         ...     ...
# 58                                    Hospital doctor   45           6   37900
# 59                                        Comptroller   39          10   92207
# 60                                             Dealer   35           2   57239
# 61                              IT sales professional   47           5   62233
# 62  Clinical scientist, histocompatibility and imm...   31          13   35690
#
# [63 rows x 7 columns]

# %% [markdown]
# #### Notice, that after the second % it can be blank

# %%
query = """
SELECT * FROM jobs
WHERE Name LIKE "%her%"

"""
sql_query(query)
# Out:
#             Name    Surname               Country
# 0         Cheryl     Arnold              Pakistan  \
# 1      Katherine  Rodriguez  Netherlands Antilles
# 2         Sherri   Garrison        Cayman Islands
# 3      Katherine   Gonzalez          Burkina Faso
# 4      Katherine      White               Nigeria
# ..           ...        ...                   ...
# 373  Christopher     Turner                Gambia
# 374  Christopher    Roberts           Isle of Man
# 375  Christopher     Garcia               Armenia
# 376  Christopher     Dennis                 Egypt
# 377  Christopher      Rocha              Cameroon
#
#                                    Job  Age  Experience  Salary
# 0                  Colour technologist   27           2   90405
# 1                           Contractor   42           5   88961
# 2    Planning and development surveyor   46          11   66866
# 3       Furniture conservator/restorer   29           2   93964
# 4                   Production manager   33           6   76129
# ..                                 ...  ...         ...     ...
# 373     Television/film/video producer   46           2   82636
# 374             Psychotherapist, child   39           8   76534
# 375                      Meteorologist   48          10   41000
# 376                   Graphic designer   31           5   39089
# 377               Optician, dispensing   45          13   59197
#
# [378 rows x 7 columns]

# %% [markdown]
# #### We can add a NOT in front

# %%
query = """
SELECT * FROM jobs
WHERE Name NOT LIKE "%her%"

"""
sql_query(query)
# Out:
#             Name    Surname     Country                                   Job
# 0       Jennifer      Gomez       Benin                      Engineer, mining  \
# 1          Julia    Garrett       Italy                            Bookseller
# 2       Courtney    Freeman        Niue                  Pharmacist, hospital
# 3         Sheena   Faulkner        Peru             Estate manager/land agent
# 4        Stephen   Gonzalez      Gambia                 Merchant navy officer
# ...          ...        ...         ...                                   ...
# 9617     Makayla     Miller      Kuwait                         Stage manager
# 9618     William  Underwood        Mali      Training and development officer
# 9619       Scott      Lewis  Montenegro  International aid/development worker
# 9620  Jacqueline       Diaz   Venezuela            Contracting civil engineer
# 9621     Gregory      Davis  Luxembourg                    Secretary, company
#
#       Age  Experience  Salary
# 0      27           9   79156
# 1      58           1   67262
# 2      44          15   44105
# 3      56           6   71914
# 4      26           4   50366
# ...   ...         ...     ...
# 9617   26           3   41031
# 9618   31           3   77919
# 9619   40           3   84261
# 9620   50          10   94421
# 9621   35           6   47573
#
# [9622 rows x 7 columns]

# %%
query = """
SELECT * FROM jobs
WHERE Name LIKE "B%" AND Surname NOT LIKE "M%"

"""
sql_query(query)
# Out:
#          Name   Surname                   Country
# 0     Barbara    Hodges                Seychelles  \
# 1    Brittney   Burnett                Luxembourg
# 2       Brent     Hardy                    Tuvalu
# 3     Bradley      Page                    Guyana
# 4    Benjamin      Kane  Central African Republic
# ..        ...       ...                       ...
# 446   Brandon    Harris           Kyrgyz Republic
# 447   Brandon  Anderson                Kazakhstan
# 448     Brian     Jones                    Brazil
# 449     Bruce     Evans             New Caledonia
# 450     Brent  Campbell              Saudi Arabia
#
#                                     Job  Age  Experience  Salary
# 0                          TEFL teacher   57           8   34038
# 1                           Illustrator   38           9   55960
# 2             Consulting civil engineer   29          15   60984
# 3                           Optometrist   49           4   89551
# 4                  Nurse, mental health   30          10   62991
# ..                                  ...  ...         ...     ...
# 446  Public relations account executive   53           9   68037
# 447       Scientist, research (medical)   60           6   92857
# 448                      Office manager   47           4   97255
# 449            Museum education officer   39           3   90157
# 450                    Ambulance person   37           6   73308
#
# [451 rows x 7 columns]
