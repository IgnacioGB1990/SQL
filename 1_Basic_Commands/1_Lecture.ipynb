# %% [markdown]
# ## Lecture Objectives:
#
# - `SELECT` columns `FROM` table
# - `AND`, `OR` and `NOT`
# - `DISTINCT`
# - `COUNT`
# - `WHERE`
# - `ORDER BY`
# - `LIMIT`
# - `BETWEEN`
# - `IN`
# - `LIKE` and `ILIKE`

# %% [markdown]
# #### Import Libraries

# %%
import numpy as np
import pandas as pd
import sqlite3

# %% [markdown]
# ### Convert existing csv to SQL

# %%
# Read csv as pandas Data Frame
df = pd.read_csv("./data/pokemon.csv")
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### We are going to rename the certain titles that have spaces in between

# %%
df = df.rename(columns={'Type 1': 'Type_1', 'Type 2': 'Type_2', 'Sp. Atk': 'Sp_Atk','Sp. Def': 'Sp_Def'})

# %% [markdown]
# ### Two ways we can store our database with sqlite3:

# %% [markdown]
# ### Locally

# %%
# # Establish a connection to a SQLite database and create a cursor object
# conn = sqlite3.connect('mydatabase.db')
# cursor = conn.cursor()

# # Create a table in the database ( we will add IF NOT EXISTS)
# create_table_query = """
# CREATE TABLE IF NOT EXISTS pokemon (
#     `#` INT PRIMARY KEY,
#     Name TEXT,
#     Type1 TEXT,
#     Type2 TEXT,
#     Total INT,
#     HP INT,
#     Attack INT,
#     Defense INT,
#     Sp_Atk INT,
#     Sp_Def INT,
#     Speed INT,
#     Generation INT,
#     Legendary BOOL
#     )
# """
# cursor.execute(create_table_query)


# # Append the existing DataFrame to the table
# df.to_sql('pokemon', conn, if_exists='append', index=False)

# %%
cnx = sqlite3.connect('./data/poke_database.db')

# Convert DataFrame to SQL
df.to_sql('pokemon', con=cnx, if_exists='replace', index=False)
# Create function to perform queries:
def sql_query(query):
    return pd.read_sql(query, cnx)

# %% [markdown]
# ### Let´s check we can query our table

# %%
query = """
SELECT *
FROM pokemon

LIMIT 5

"""
sql_query(query)
# Out:
#    #                   Name Type_1  Type_2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire    None    309  39      52       43
#
#    Sp_Atk  Sp_Def  Speed  Generation  Legendary
# 0      65      65     45           1          0
# 1      80      80     60           1          0
# 2     100     100     80           1          0
# 3     122     120     80           1          0
# 4      60      50     65           1          0

# %% [markdown]
# ### `SELECT` columns `FROM` table

# %%
query = """
SELECT Total, HP, Speed FROM pokemon
"""
sql_query(query)
# Out:
#      Total  HP  Speed
# 0      318  45     45
# 1      405  60     60
# 2      525  80     80
# 3      625  80     80
# 4      309  39     65
# ..     ...  ..    ...
# 795    600  50     50
# 796    700  50    110
# 797    600  80     70
# 798    680  80     80
# 799    600  80     70
#
# [800 rows x 3 columns]

# %% [markdown]
# ### `DISTINCT` return how many unique values are there in a column

# %%
query = """
SELECT DISTINCT Type_2 FROM pokemon

"""
sql_query(query)
# Out:
#       Type_2
# 0     Poison
# 1       None
# 2     Flying
# 3     Dragon
# 4     Ground
# 5      Fairy
# 6      Grass
# 7   Fighting
# 8    Psychic
# 9      Steel
# 10       Ice
# 11      Rock
# 12      Dark
# 13     Water
# 14  Electric
# 15      Fire
# 16     Ghost
# 17       Bug
# 18    Normal

# %% [markdown]
# ### `COUNT` is a function and needs to be wrapped with ( )

# %%
query = """
SELECT COUNT( DISTINCT Name) FROM pokemon

"""
sql_query(query)
# Out:
#    COUNT( DISTINCT Name)
# 0                    800

# %% [markdown]
# ### `WHERE` statement allows us to specify conditions on columns for the rows to be returned

# %%
query = """
SELECT Name, Type_2, Attack FROM pokemon
WHERE Type_2 = "Poison" AND HP >50

"""
sql_query(query)
# Out:
#                      Name  Type_2  Attack
# 0                 Ivysaur  Poison      62
# 1                Venusaur  Poison      82
# 2   VenusaurMega Venusaur  Poison     100
# 3                Beedrill  Poison      90
# 4   BeedrillMega Beedrill  Poison     150
# 5                   Gloom  Poison      65
# 6               Vileplume  Poison      80
# 7                 Venonat  Poison      55
# 8                Venomoth  Poison      65
# 9              Weepinbell  Poison      90
# 10             Victreebel  Poison     105
# 11             Tentacruel  Poison      70
# 12                 Gengar  Poison      65
# 13      GengarMega Gengar  Poison      65
# 14                Ariados  Poison      90
# 15               Qwilfish  Poison      95
# 16                 Dustox  Poison      50
# 17               Roserade  Poison      70
# 18              Scolipede  Poison     100
# 19                Foongus  Poison      55
# 20              Amoonguss  Poison      85

# %% [markdown]
# ### `ORDER BY` will help you sort rows based on column value, in either ascending or descending order.
#
# - use `ASC` to sort in ascending order
# - use `DESC` to sort in descending order
# - If you leave it blank, `ORDER BY` uses `ASC` by default.
#
# It is placed towards the end of the query. We want to do any selection and filtering first, before finally sorting.

# %%
query = """
SELECT Name, Type_2, Attack FROM pokemon
WHERE Type_2 = "Poison" AND HP >50
ORDER BY Type_2 Desc,Attack ASC

"""
sql_query(query)
# Out:
#                      Name  Type_2  Attack
# 0                  Dustox  Poison      50
# 1                 Venonat  Poison      55
# 2                 Foongus  Poison      55
# 3                 Ivysaur  Poison      62
# 4                   Gloom  Poison      65
# 5                Venomoth  Poison      65
# 6                  Gengar  Poison      65
# 7       GengarMega Gengar  Poison      65
# 8              Tentacruel  Poison      70
# 9                Roserade  Poison      70
# 10              Vileplume  Poison      80
# 11               Venusaur  Poison      82
# 12              Amoonguss  Poison      85
# 13               Beedrill  Poison      90
# 14             Weepinbell  Poison      90
# 15                Ariados  Poison      90
# 16               Qwilfish  Poison      95
# 17  VenusaurMega Venusaur  Poison     100
# 18              Scolipede  Poison     100
# 19             Victreebel  Poison     105
# 20  BeedrillMega Beedrill  Poison     150

# %% [markdown]
# ### `LIMIT` allows us to limit the number of rows returned for a query.

# %%
query = """
SELECT Name, Type_2, Attack FROM pokemon
WHERE Type_2 = "Poison" AND HP >50
ORDER BY Type_2 Desc,Attack ASC

LIMIT 3

"""
sql_query(query)
# Out:
#       Name  Type_2  Attack
# 0   Dustox  Poison      50
# 1  Venonat  Poison      55
# 2  Foongus  Poison      55

# %% [markdown]
# ### `BETWEEN` operator can be used to match a value against a range of values:
# - value BETWEEN low AND high
#
# It is the same as saying:
# - value \>= low AND value \<= high
#
# Can combine with `NOT BETWEEN`:
# - value \< low OR value \> high
# - value NOT BETWEEN low AND high
#
# Can also be used with dates. Note that you need to format dates in the ISO 8601 standard format, which is YYYY-MM-DD
# - date BETWEEN "2007-01-01" AND "2007-02-01"

# %%
query = """
SELECT Name, Attack , Defense , Speed FROM pokemon
WHERE Attack BETWEEN 50 AND 80 
AND  Defense NOT BETWEEN 60 AND 70

"""
sql_query(query)
# Out:
#            Name  Attack  Defense  Speed
# 0    Charmander      52       43     65
# 1    Charmeleon      64       58     80
# 2     Wartortle      63       80     58
# 3     Pidgeotto      60       55     71
# 4       Pidgeot      80       75    101
# ..          ...     ...      ...    ...
# 249     Sliggoo      75       53     60
# 250      Klefki      80       91     75
# 251    Phantump      70       48     38
# 252    Bergmite      69       85     28
# 253     Noivern      70       80    123
#
# [254 rows x 4 columns]

# %% [markdown]
# ### `IN`

# %%
query = """
SELECT COUNT(*) FROM pokemon
WHERE HP IN (100, 105)

"""
sql_query(query)
# Out:
#    COUNT(*)
# 0        42

# %% [markdown]
# ### `LIKE` (case-sensitive) and `ILIKE` (case-insensitive) operator allows us to perform pattern matching against string data with the use of wildcard characters.
#
# - Percent %
#     - Matches any sequence of characters
# - Underscore _
#     - Matches any single character
#
# Examples %:
# - All names that begin with an "A"
#     - `WHERE` name `LIKE` 'A%'
# - All names that end with an 'a'
#     - `WHERE` name `LIKE` '%a'
#
# Examples _:
# - Using the underscore allows us to replace just a single character.
#     - Get all pokemon
#     - WHERE name LIKE 'Char_"
#
# - You can use multiple underscores
# - Imagine we had version string codes in the format 'Version#A4', 'Version#B7', etc ...
#     - WHERE value LIKE 'Version# _ _'
# - We can also combine pattern matching operators to create more complex patterns
#     - WHERE name LIKE '`_`her`%`'
#         - `C`her`yl`
#         - `T`her`esa`
#         - `S`her`ri`

# %%
query = """
SELECT * FROM pokemon
WHERE Name LIKE "_her%"

"""
sql_query(query)
# Out:
#      #     Name Type_1 Type_2  Total  HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 0  420  Cherubi  Grass   None    275  45      35       45      62      53
# 1  421  Cherrim  Grass   None    450  70      60       70      87      78
#
#    Speed  Generation  Legendary
# 0     35           4          0
# 1     85           4          0

# %% [markdown]
# #### Notice, that after the second % it can be blank

# %%
query = """
SELECT * FROM pokemon
WHERE Name LIKE "%her%"

"""
sql_query(query)
# Out:
#      #                     Name    Type_1    Type_2  Total  HP  Attack  \
# 0  123                  Scyther       Bug    Flying    500  70     110
# 1  214                Heracross       Bug  Fighting    500  80     125
# 2  214  HeracrossMega Heracross       Bug  Fighting    600  80     185
# 3  420                  Cherubi     Grass      None    275  45      35
# 4  421                  Cherrim     Grass      None    450  70      60
# 5  507                  Herdier    Normal      None    370  65      80
# 6  641    TornadusTherian Forme    Flying      None    580  79     100
# 7  642   ThundurusTherian Forme  Electric    Flying    580  79     105
# 8  645    LandorusTherian Forme    Ground    Flying    600  89     145
# 9  692                Clauncher     Water      None    330  50      53
#
#    Defense  Sp_Atk  Sp_Def  Speed  Generation  Legendary
# 0       80      55      80    105           1          0
# 1       75      40      95     85           2          0
# 2      115      40     105     75           2          0
# 3       45      62      53     35           4          0
# 4       70      87      78     85           4          0
# 5       65      35      65     60           5          0
# 6       80     110      90    121           5          1
# 7       70     145      80    101           5          1
# 8       90     105      80     91           5          1
# 9       62      58      63     44           6          0

# %% [markdown]
# #### We can add a NOT in front

# %%
query = """
SELECT * FROM pokemon
WHERE Name NOT LIKE "%her%"

"""
sql_query(query)
# Out:
#        #                   Name   Type_1  Type_2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire    None    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 785  719                Diancie     Rock   Fairy    600  50     100      150
# 786  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 787  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 788  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 789  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp_Atk  Sp_Def  Speed  Generation  Legendary
# 0        65      65     45           1          0
# 1        80      80     60           1          0
# 2       100     100     80           1          0
# 3       122     120     80           1          0
# 4        60      50     65           1          0
# ..      ...     ...    ...         ...        ...
# 785     100     150     50           6          1
# 786     160     110    110           6          1
# 787     150     130     70           6          1
# 788     170     130     80           6          1
# 789     130      90     70           6          1
#
# [790 rows x 13 columns]

# %%
query = """
SELECT * FROM pokemon
WHERE Name LIKE "B%" AND Type_2 NOT LIKE "N%"
ORDER BY Type_2

"""
sql_query(query)
# Out:
#       #                   Name  Type_1    Type_2  Total   HP  Attack  Defense  \
# 0   257               Blaziken    Fire  Fighting    530   80     120       70
# 1   257  BlazikenMega Blaziken    Fire  Fighting    630   80     160       80
# 2   286                Breloom   Grass  Fighting    460   60     130       80
# 3    12             Butterfree     Bug    Flying    395   60      45       50
# 4   267              Beautifly     Bug    Flying    395   60      70       50
# 5   628               Braviary  Normal    Flying    510  100     123       75
# 6   339               Barboach   Water    Ground    288   50      48       43
# 7     1              Bulbasaur   Grass    Poison    318   45      49       49
# 8    15               Beedrill     Bug    Poison    395   65      90       40
# 9    15  BeedrillMega Beedrill     Bug    Poison    495   65     150       40
# 10   69             Bellsprout   Grass    Poison    300   50      75       35
# 11  406                  Budew   Grass    Poison    280   40      30       35
# 12  343                 Baltoy  Ground   Psychic    300   40      40       55
# 13  374                 Beldum   Steel   Psychic    300   40      55       80
# 14  436                Bronzor   Steel   Psychic    300   57      24       86
# 15  437               Bronzong   Steel   Psychic    500   67      89      116
# 16  411              Bastiodon    Rock     Steel    495   60      52      168
# 17  625                Bisharp    Dark     Steel    490   65     125      100
# 18  400                Bibarel  Normal     Water    410   79      85       60
# 19  688                Binacle    Rock     Water    306   42      52       67
# 20  689             Barbaracle    Rock     Water    500   72     105      115
#
#     Sp_Atk  Sp_Def  Speed  Generation  Legendary
# 0      110      70     80           3          0
# 1      130      80    100           3          0
# 2       60      60     70           3          0
# 3       90      80     70           1          0
# 4      100      50     65           3          0
# 5       57      75     80           5          0
# 6       46      41     60           3          0
# 7       65      65     45           1          0
# 8       45      80     75           1          0
# 9       15      80    145           1          0
# 10      70      30     40           1          0
# 11      50      70     55           4          0
# 12      40      70     55           3          0
# 13      35      60     30           3          0
# 14      24      86     23           4          0
# 15      79     116     33           4          0
# 16      47     138     30           4          0
# 17      60      70     70           5          0
# 18      55      60     71           4          0
# 19      39      56     50           6          0
# 20      54      86     68           6          0
